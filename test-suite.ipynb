# %%
from scidash_api import client
import pprint

client_instance = client.ScidashClient()

client_instance.login(username='admin_test', password='admin_test')

print(client_instance.token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoxLCJ1c2VybmFtZSI6ImFkbWluIiwiZXhwIjoxNTE5OTgzNjA5LCJlbWFpbCI6ImFkbWluQGFkbWluLmNjIn0.6-hLT1mBukKH7ZN811wgdhQMr_HbnpB7nNNlgrG_8Dc

# %%
with open('raw_score_matrix_sample.json') as f:
            score_matrix = f.read()

# %%
with open('raw_suite_sample.json') as f:
            suite = f.read()

# %%
import json
suite = json.loads(suite)
score_matrix = json.loads(score_matrix)

responses = client_instance.upload_suite(suite, score_matrix.get('scores'))

# %%
for response in responses:
    pprint.pprint(response.json())
# Out:
# {'data': {'id': 60,
#           'model_instance': {'attributes': {},
#                              'id': 59,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 303},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 304},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 305},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 306},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 307},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 308}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 59,
#                                              'url': ''},
#                              'name': 'Izhikevich',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-02-19T08:52:00.562600',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 7.0,
#           'raw': '-0.3333',
#           'related_data': {},
#           'score': -0.3333333333333333,
#           'score_type': 'ZScore',
#           'sort_key': 0.7388826803635273,
#           'summary': '=== Model Izhikevich achieved score Z = -0.33 on test '
#                      "'MyTest'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 63,
#                             'observation': {'mean': '8',
#                                             'std': '3',
#                                             'url': 'http://somewhere.thathasdata.com'},
#                             'test_class': {'class_name': 'MyTest',
#                                            'id': 63,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 34,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-02-19T08:52:00.562600',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-03-02T09:35:09.181144'}],
#                             'timestamp': '2018-03-02T09:35:09.172620',
#                             'verbose': 1},
#           'timestamp': '2018-03-02T09:35:09.219322'},
#  'success': True}
# {'data': {'id': 61,
#           'model_instance': {'attributes': {},
#                              'id': 60,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 309},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 310},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 311},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 312},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 313},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 314}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 60,
#                                              'url': ''},
#                              'name': 'Izhikevich',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-02-19T08:52:00.562600',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 7.0,
#           'raw': '0',
#           'related_data': {},
#           'score': 0.0,
#           'score_type': 'ZScore',
#           'sort_key': 1.0,
#           'summary': '=== Model Izhikevich achieved score Z = 0.00 on test '
#                      "'Second Test'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 64,
#                             'observation': {'mean': '7',
#                                             'std': '3.8',
#                                             'url': 'http://somewhereelse.thathasdata.com'},
#                             'test_class': {'class_name': 'Second Test',
#                                            'id': 64,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 34,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-02-19T08:52:00.562600',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-03-02T09:35:09.181144'}],
#                             'timestamp': '2018-03-02T09:35:09.348493',
#                             'verbose': 1},
#           'timestamp': '2018-03-02T09:35:09.391954'},
#  'success': True}
# {'data': {'id': 62,
#           'model_instance': {'attributes': {'izhikevich2007Cell': {'a': '0.04 '
#                                                                         'per_ms'}},
#                              'id': 61,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 315},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 316},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 317},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 318},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 319},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 320}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 61,
#                                              'url': ''},
#                              'name': 'Izhikevich_new',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-02-19T08:52:00.562600',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 8.0,
#           'raw': '0',
#           'related_data': {},
#           'score': 0.0,
#           'score_type': 'ZScore',
#           'sort_key': 1.0,
#           'summary': '=== Model Izhikevich_new achieved score Z = 0.00 on test '
#                      ';MyTest;. ===',
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 65,
#                             'observation': {'mean': '8',
#                                             'std': '3',
#                                             'url': 'http://somewhere.thathasdata.com'},
#                             'test_class': {'class_name': 'MyTest',
#                                            'id': 65,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 34,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-02-19T08:52:00.562600',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-03-02T09:35:09.181144'}],
#                             'timestamp': '2018-03-02T09:35:09.499845',
#                             'verbose': 1},
#           'timestamp': '2018-03-02T09:35:09.541228'},
#  'success': True}
# {'data': {'id': 63,
#           'model_instance': {'attributes': {'izhikevich2007Cell': {'a': '0.04 '
#                                                                         'per_ms'}},
#                              'id': 62,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 321},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 322},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 323},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 324},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 325},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 326}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 62,
#                                              'url': ''},
#                              'name': 'Izhikevich_new',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-02-19T08:52:00.562600',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 8.0,
#           'raw': '0.2632',
#           'related_data': {},
#           'score': 0.2631578947368421,
#           'score_type': 'ZScore',
#           'sort_key': 0.7924288824046,
#           'summary': '=== Model Izhikevich_new achieved score Z = 0.26 on test '
#                      "'Second Test'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 66,
#                             'observation': {'mean': '7',
#                                             'std': '3.8',
#                                             'url': 'http://somewhereelse.thathasdata.com'},
#                             'test_class': {'class_name': 'Second Test',
#                                            'id': 66,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 34,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-02-19T08:52:00.562600',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-03-02T09:35:09.181144'}],
#                             'timestamp': '2018-03-02T09:35:09.657711',
#                             'verbose': 1},
#           'timestamp': '2018-03-02T09:35:09.699161'},
#  'success': True}

# %%
from scidash_api import client
import pprint

client_instance = client.ScidashClient({"base_url": "http://localhost:8000"})

client_instance.login(username='admin', password='kavabanga')

print(client_instance.token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoxLCJ1c2VybmFtZSI6ImFkbWluIiwiZXhwIjoxNTIzMzU4Nzg3LCJlbWFpbCI6ImFkbWluQGFkbWluLmNjIn0.5D7WJxNWGlr3eU-GhFXayywyKpfehvt8hs225NmiTlk

# %%
with open('test_data/raw_score_matrix_sample.json') as f:
            score_matrix = f.read()

# %%
with open('test_data/raw_suite_sample.json') as f:
            suite = f.read()

# %%
import json
suite = json.loads(suite)
score_matrix = json.loads(score_matrix)

responses = client_instance.upload_suite(suite, score_matrix.get('scores'))

# %%
for response in responses:
    pprint.pprint(response.json())
# Out:
# {'data': {'id': 145,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 151,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 855},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 856},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 857},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 858},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 859},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 860}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 151,
#                                              'url': ''},
#                              'name': 'Izhikevich',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-03-28T11:56:38.545021',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': {'dict': 'for testing dict handling too'},
#           'raw': '-0.3333',
#           'related_data': {},
#           'score': -0.3333333333333333,
#           'score_type': 'ZScore',
#           'sort_key': 0.7388826803635273,
#           'summary': '=== Model Izhikevich achieved score Z = -0.33 on test '
#                      "'MyTest'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 155,
#                             'observation': {'mean': '8',
#                                             'std': '3',
#                                             'url': 'http://somewhere.thathasdata.com'},
#                             'test_class': {'class_name': 'MyTest',
#                                            'id': 155,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 49,
#                                              'name': 'My Suite 6',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-03-28T11:56:38.545021',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-10T11:08:07.224907'}],
#                             'timestamp': '2018-04-10T11:08:07.216150',
#                             'verbose': 1},
#           'timestamp': '2018-04-10T11:08:07.262756'},
#  'success': True}
# {'data': {'id': 146,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 152,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 861},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 862},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 863},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 864},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 865},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 866}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 152,
#                                              'url': ''},
#                              'name': 'Izhikevich',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-03-28T11:56:38.545021',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 7.0,
#           'raw': '0',
#           'related_data': {},
#           'score': 0.0,
#           'score_type': 'ZScore',
#           'sort_key': 1.0,
#           'summary': '=== Model Izhikevich achieved score Z = 0.00 on test '
#                      "'Second Test'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 156,
#                             'observation': {'mean': '7',
#                                             'std': '3.8',
#                                             'url': 'http://somewhereelse.thathasdata.com'},
#                             'test_class': {'class_name': 'Second Test',
#                                            'id': 156,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 49,
#                                              'name': 'My Suite 6',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-03-28T11:56:38.545021',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-10T11:08:07.224907'}],
#                             'timestamp': '2018-04-10T11:08:07.467110',
#                             'verbose': 1},
#           'timestamp': '2018-04-10T11:08:07.525317'},
#  'success': True}
# {'data': {'id': 147,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 153,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 867},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 868},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 869},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 870},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 871},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 872}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 153,
#                                              'url': ''},
#                              'name': 'Izhikevich_new',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-03-28T11:56:38.545021',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 8.0,
#           'raw': '0',
#           'related_data': {},
#           'score': 0.0,
#           'score_type': 'ZScore',
#           'sort_key': 1.0,
#           'summary': '=== Model Izhikevich_new achieved score Z = 0.00 on  '
#                      "test 'MyTest'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 157,
#                             'observation': {'mean': '8',
#                                             'std': '3',
#                                             'url': 'http://somewhere.thathasdata.com'},
#                             'test_class': {'class_name': 'MyTest',
#                                            'id': 157,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 49,
#                                              'name': 'My Suite 6',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-03-28T11:56:38.545021',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-10T11:08:07.224907'}],
#                             'timestamp': '2018-04-10T11:08:07.731858',
#                             'verbose': 1},
#           'timestamp': '2018-04-10T11:08:07.836906'},
#  'success': True}
# {'data': {'id': 148,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 154,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 873},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 874},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 875},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 876},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 877},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 878}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 154,
#                                              'url': ''},
#                              'name': 'Izhikevich_new',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-03-28T11:56:38.545021',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 8.0,
#           'raw': '0.2632',
#           'related_data': {},
#           'score': 0.2631578947368421,
#           'score_type': 'ZScore',
#           'sort_key': 0.7924288824046,
#           'summary': '=== Model Izhikevich_new achieved score Z = 0.26 on  est '
#                      "'Second Test'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 158,
#                             'observation': {'mean': '7',
#                                             'std': '3.8',
#                                             'url': 'http://somewhereelse.thathasdata.com'},
#                             'test_class': {'class_name': 'Second Test',
#                                            'id': 158,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 49,
#                                              'name': 'My Suite 6',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-03-28T11:56:38.545021',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-10T11:08:07.224907'}],
#                             'timestamp': '2018-04-10T11:08:08.019652',
#                             'verbose': 1},
#           'timestamp': '2018-04-10T11:08:08.089760'},
#  'success': True}

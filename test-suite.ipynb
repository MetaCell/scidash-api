# %%
from scidash_api import client
import pprint

client_instance = client.ScidashClient({"base_url": "http://localhost:8000"})

client_instance.login(username='admin', password='admin_test')

print(client_instance.token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoxLCJ1c2VybmFtZSI6ImFkbWluIiwiZXhwIjoxNTI0NjgwNDc2LCJlbWFpbCI6ImFkbWluQGFkbWluLmNjIn0.QdpbDGjF8HBSZXD7yYp6BteVFlSZGHMD0S_CCUue6s4

# %%
with open('test_data/raw_score_matrix_sample.json') as f:
            score_matrix = f.read()

# %%
with open('test_data/raw_suite_sample.json') as f:
            suite = f.read()

# %%
import json
suite = json.loads(suite)
score_matrix = json.loads(score_matrix)

responses = client_instance.upload_suite_score(suite, score_matrix)

# %%
for response in responses:
    pprint.pprint(response.json())
# Out:
# {'data': {'id': 26,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 26,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 7},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 8},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 9},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 10},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 11},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 12}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 2,
#                                              'url': 'http://test-url.for/not-spaming-data/in-database'},
#                              'name': 'Izhikevich',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2018-04-18T13:22:09.923441',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-04-18T13:41:15.705528',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$WzktojIdEDch$Fdw1dgoamPo7kMdGlvdw//HLxvDQE8SAlHCK5UrNQ6I=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': {'dict': 'for testing dict handling too'},
#           'raw': '-0.3333',
#           'related_data': {},
#           'score': -0.3333333333333333,
#           'score_class': {'class_name': 'ZScore',
#                           'id': 1,
#                           'url': 'http://test-url.for/not-spaming-data/in-database'},
#           'score_type': 'ZScore',
#           'sort_key': 0.7388826803635273,
#           'summary': '=== Model Izhikevich achieved score Z = -0.33 on test '
#                      "'MyTest'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit/Darwin',
#                             'description': None,
#                             'hostname': None,
#                             'id': 26,
#                             'observation': {'mean': '8',
#                                             'std': '3',
#                                             'url': 'http://somewhere.thathasdata.com'},
#                             'test_class': {'class_name': 'MyTest',
#                                            'id': 2,
#                                            'url': 'http://test-url.for/not-spaming-data/in-database'},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 3,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2018-04-18T13:22:09.923441',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-04-18T13:41:15.705528',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$WzktojIdEDch$Fdw1dgoamPo7kMdGlvdw//HLxvDQE8SAlHCK5UrNQ6I=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-23T18:34:04.465001'}],
#                             'timestamp': '2018-04-25T18:16:16.875618',
#                             'verbose': 1},
#           'timestamp': '2018-04-25T18:16:16.927186'},
#  'success': True}
# {'data': {'id': 27,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 27,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 7},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 8},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 9},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 10},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 11},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 12}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 2,
#                                              'url': 'http://test-url.for/not-spaming-data/in-database'},
#                              'name': 'Izhikevich',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2018-04-18T13:22:09.923441',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-04-18T13:41:15.705528',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$WzktojIdEDch$Fdw1dgoamPo7kMdGlvdw//HLxvDQE8SAlHCK5UrNQ6I=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 7.0,
#           'raw': '0',
#           'related_data': {},
#           'score': 0.0,
#           'score_class': {'class_name': 'ZScore',
#                           'id': 1,
#                           'url': 'http://test-url.for/not-spaming-data/in-database'},
#           'score_type': 'ZScore',
#           'sort_key': 1.0,
#           'summary': '=== Model Izhikevich achieved score Z = 0.00 on test '
#                      "'Second Test'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit/Darwin',
#                             'description': None,
#                             'hostname': None,
#                             'id': 27,
#                             'observation': {'mean': '7',
#                                             'std': '3.8',
#                                             'url': 'http://somewhereelse.thathasdata.com'},
#                             'test_class': {'class_name': 'Second Test',
#                                            'id': 2,
#                                            'url': 'http://test-url.for/not-spaming-data/in-database'},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 3,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2018-04-18T13:22:09.923441',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-04-18T13:41:15.705528',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$WzktojIdEDch$Fdw1dgoamPo7kMdGlvdw//HLxvDQE8SAlHCK5UrNQ6I=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-23T18:34:04.465001'}],
#                             'timestamp': '2018-04-25T18:16:17.068311',
#                             'verbose': 1},
#           'timestamp': '2018-04-25T18:16:17.123788'},
#  'success': True}
# {'data': {'id': 28,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 28,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 7},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 8},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 9},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 10},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 11},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 12}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 2,
#                                              'url': 'http://test-url.for/not-spaming-data/in-database'},
#                              'name': 'Izhikevich_new',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2018-04-18T13:22:09.923441',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-04-18T13:41:15.705528',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$WzktojIdEDch$Fdw1dgoamPo7kMdGlvdw//HLxvDQE8SAlHCK5UrNQ6I=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 8.0,
#           'raw': '0',
#           'related_data': {},
#           'score': 0.0,
#           'score_class': {'class_name': 'ZScore',
#                           'id': 1,
#                           'url': 'http://test-url.for/not-spaming-data/in-database'},
#           'score_type': 'ZScore',
#           'sort_key': 1.0,
#           'summary': '=== Model Izhikevich_new achieved score Z = 0.00 on  '
#                      "test 'MyTest'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit/Darwin',
#                             'description': None,
#                             'hostname': None,
#                             'id': 28,
#                             'observation': {'mean': '8',
#                                             'std': '3',
#                                             'url': 'http://somewhere.thathasdata.com'},
#                             'test_class': {'class_name': 'MyTest',
#                                            'id': 2,
#                                            'url': 'http://test-url.for/not-spaming-data/in-database'},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 3,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2018-04-18T13:22:09.923441',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-04-18T13:41:15.705528',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$WzktojIdEDch$Fdw1dgoamPo7kMdGlvdw//HLxvDQE8SAlHCK5UrNQ6I=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-23T18:34:04.465001'}],
#                             'timestamp': '2018-04-25T18:16:17.283442',
#                             'verbose': 1},
#           'timestamp': '2018-04-25T18:16:17.332092'},
#  'success': True}
# {'data': {'id': 29,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 29,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 7},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 8},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 9},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 10},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 11},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 12}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 2,
#                                              'url': 'http://test-url.for/not-spaming-data/in-database'},
#                              'name': 'Izhikevich_new',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2018-04-18T13:22:09.923441',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-04-18T13:41:15.705528',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$WzktojIdEDch$Fdw1dgoamPo7kMdGlvdw//HLxvDQE8SAlHCK5UrNQ6I=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 8.0,
#           'raw': '0.2632',
#           'related_data': {},
#           'score': 0.2631578947368421,
#           'score_class': {'class_name': 'ZScore',
#                           'id': 1,
#                           'url': 'http://test-url.for/not-spaming-data/in-database'},
#           'score_type': 'ZScore',
#           'sort_key': 0.7924288824046,
#           'summary': '=== Model Izhikevich_new achieved score Z = 0.26 on  est '
#                      "'Second Test'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit/Darwin',
#                             'description': None,
#                             'hostname': None,
#                             'id': 29,
#                             'observation': {'mean': '7',
#                                             'std': '3.8',
#                                             'url': 'http://somewhereelse.thathasdata.com'},
#                             'test_class': {'class_name': 'Second Test',
#                                            'id': 2,
#                                            'url': 'http://test-url.for/not-spaming-data/in-database'},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 3,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2018-04-18T13:22:09.923441',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-04-18T13:41:15.705528',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$WzktojIdEDch$Fdw1dgoamPo7kMdGlvdw//HLxvDQE8SAlHCK5UrNQ6I=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-23T18:34:04.465001'}],
#                             'timestamp': '2018-04-25T18:16:17.500482',
#                             'verbose': 1},
#           'timestamp': '2018-04-25T18:16:17.549837'},
#  'success': True}

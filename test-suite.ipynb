# %%
from scidash_api import client
import pprint

client_instance = client.ScidashClient({"base_url": "http://localhost:8000"})

client_instance.login(username='admin', password='admin_test')

print(client_instance.token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoxLCJ1c2VybmFtZSI6ImFkbWluIiwiZXhwIjoxNTIzNjMwNDIyLCJlbWFpbCI6ImFkbWluQGFkbWluLmNjIn0.U3Idjn7V4Iuhu51wf_lerC13hbmGpB7eV1Fw6AmbxuA

# %%
with open('test_data/raw_score_matrix_sample.json') as f:
            score_matrix = f.read()

# %%
with open('test_data/raw_suite_sample.json') as f:
            suite = f.read()

# %%
import json
suite = json.loads(suite)
score_matrix = json.loads(score_matrix)

responses = client_instance.upload_suite_score(suite, score_matrix)

# %%
for response in responses:
    pprint.pprint(response.text)
# Out:
# {'data': {'id': 191,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 197,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 1131},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 1132},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 1133},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 1134},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 1135},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 1136}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 197,
#                                              'url': ''},
#                              'name': 'Izhikevich',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-03-28T11:56:38.545021',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': {'dict': 'for testing dict handling too'},
#           'raw': '-0.3333',
#           'related_data': {},
#           'score': -0.3333333333333333,
#           'score_type': 'ZScore',
#           'sort_key': 0.7388826803635273,
#           'summary': '=== Model Izhikevich achieved score Z = -0.33 on test '
#                      "'MyTest'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 201,
#                             'observation': {'mean': '8',
#                                             'std': '3',
#                                             'url': 'http://somewhere.thathasdata.com'},
#                             'test_class': {'class_name': 'MyTest',
#                                            'id': 201,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 37,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-03-28T11:56:38.545021',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-10T11:01:32.848848'}],
#                             'timestamp': '2018-04-13T14:35:23.207883',
#                             'verbose': 1},
#           'timestamp': '2018-04-13T14:35:23.259014'},
#  'success': True}
# {'data': {'id': 192,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 198,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 1137},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 1138},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 1139},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 1140},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 1141},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 1142}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 198,
#                                              'url': ''},
#                              'name': 'Izhikevich',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-03-28T11:56:38.545021',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 7.0,
#           'raw': '0',
#           'related_data': {},
#           'score': 0.0,
#           'score_type': 'ZScore',
#           'sort_key': 1.0,
#           'summary': '=== Model Izhikevich achieved score Z = 0.00 on test '
#                      "'Second Test'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 202,
#                             'observation': {'mean': '7',
#                                             'std': '3.8',
#                                             'url': 'http://somewhereelse.thathasdata.com'},
#                             'test_class': {'class_name': 'Second Test',
#                                            'id': 202,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 37,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-03-28T11:56:38.545021',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-10T11:01:32.848848'}],
#                             'timestamp': '2018-04-13T14:35:23.393655',
#                             'verbose': 1},
#           'timestamp': '2018-04-13T14:35:23.440883'},
#  'success': True}
# {'data': {'id': 193,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 199,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 1143},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 1144},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 1145},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 1146},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 1147},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 1148}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 199,
#                                              'url': ''},
#                              'name': 'Izhikevich_new',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-03-28T11:56:38.545021',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 8.0,
#           'raw': '0',
#           'related_data': {},
#           'score': 0.0,
#           'score_type': 'ZScore',
#           'sort_key': 1.0,
#           'summary': '=== Model Izhikevich_new achieved score Z = 0.00 on  '
#                      "test 'MyTest'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 203,
#                             'observation': {'mean': '8',
#                                             'std': '3',
#                                             'url': 'http://somewhere.thathasdata.com'},
#                             'test_class': {'class_name': 'MyTest',
#                                            'id': 203,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 37,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-03-28T11:56:38.545021',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-10T11:01:32.848848'}],
#                             'timestamp': '2018-04-13T14:35:23.615787',
#                             'verbose': 1},
#           'timestamp': '2018-04-13T14:35:23.663924'},
#  'success': True}
# {'data': {'id': 194,
#           'model_instance': {'attributes': {},
#                              'backend': 'jNeuroML',
#                              'id': 200,
#                              'model_class': {'capabilities': [{'class_name': 'Runnable',
#                                                                'id': 1149},
#                                                               {'class_name': 'ReceivesCurrent',
#                                                                'id': 1150},
#                                                               {'class_name': 'ReceivesSquareCurrent',
#                                                                'id': 1151},
#                                                               {'class_name': 'ProducesActionPotentials',
#                                                                'id': 1152},
#                                                               {'class_name': 'ProducesSpikes',
#                                                                'id': 1153},
#                                                               {'class_name': 'ProducesMembranePotential',
#                                                                'id': 1154}],
#                                              'class_name': 'ReducedModel',
#                                              'id': 200,
#                                              'url': ''},
#                              'name': 'Izhikevich_new',
#                              'run_params': {},
#                              'url': 'https://github.com/scidash/neuronunit/blob/master/neuronunit/models/NeuroML2/LEMS_2007One.xml'},
#           'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                     'email': 'admin@admin.cc',
#                     'first_name': '',
#                     'groups': [],
#                     'id': 1,
#                     'is_active': True,
#                     'is_staff': True,
#                     'is_superuser': True,
#                     'last_login': '2018-03-28T11:56:38.545021',
#                     'last_name': '',
#                     'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                     'user_permissions': [],
#                     'username': 'admin'},
#           'prediction': 8.0,
#           'raw': '0.2632',
#           'related_data': {},
#           'score': 0.2631578947368421,
#           'score_type': 'ZScore',
#           'sort_key': 0.7924288824046,
#           'summary': '=== Model Izhikevich_new achieved score Z = 0.26 on  est '
#                      "'Second Test'. ===",
#           'test_instance': {'build_info': 'Darwin-17.4.0-x86_64-i386-64bit',
#                             'description': None,
#                             'hostname': None,
#                             'id': 204,
#                             'observation': {'mean': '7',
#                                             'std': '3.8',
#                                             'url': 'http://somewhereelse.thathasdata.com'},
#                             'test_class': {'class_name': 'Second Test',
#                                            'id': 204,
#                                            'url': ''},
#                             'test_suites': [{'hash': 'a13dfda290ce1de94110b4b94e9283c939fc6e161f7a732f9ab70f94',
#                                              'id': 37,
#                                              'name': 'My Suite',
#                                              'owner': {'date_joined': '2017-12-05T17:55:40.945208',
#                                                        'email': 'admin@admin.cc',
#                                                        'first_name': '',
#                                                        'groups': [],
#                                                        'id': 1,
#                                                        'is_active': True,
#                                                        'is_staff': True,
#                                                        'is_superuser': True,
#                                                        'last_login': '2018-03-28T11:56:38.545021',
#                                                        'last_name': '',
#                                                        'password': 'pbkdf2_sha256$36000$iv7V4jEAuMiS$w0cQz/8ZwPr0JeQ0aXvCeLBOX9rlNVf+ueQEa4mv2Ag=',
#                                                        'user_permissions': [],
#                                                        'username': 'admin'},
#                                              'timestamp': '2018-04-10T11:01:32.848848'}],
#                             'timestamp': '2018-04-13T14:35:23.813164',
#                             'verbose': 1},
#           'timestamp': '2018-04-13T14:35:23.853720'},
#  'success': True}
